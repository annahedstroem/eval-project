# %% [markdown]
# <h1>20 newsgroups dataset</h1>
# <table>
#     <thead>
#         <tr>
#             <th>Qmean distributions</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>This plot shows the distribution of qmean for each sample used (named 10, 20, 30, 40, and 50, respectively). The activation of the explained class in the model is shown between brackets in the legend.
#             <br />
#             Model test accuracy is listed next to the model name.
#             </td>
#         </tr>
#         <tr>
#             <td>Trained 0.78</td>
#         </tr>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/20newsgroups-truncated__0_qmean_dists.png" target="blank"><img src="../results/plots/20newsgroups-truncated_0__qmean_dists.png" alt="Qmean distributions - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="2">Correct pairs</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Data</td>
#             <td>Trained 0.78</td>
#         </tr>
#         <tr>
#             <td>Random</td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/20newsgroups-truncated_0_softmax_correct_pairs.png" target="blank"><img src="../results/plots/20newsgroups-truncated___correct_pairs.png" alt="Correct pairs - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#         <tr>
#             <td>Genetic</td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/20newsgroups-truncated___genetic_correct_pairs.png" target="blank"><img src="../results/plots/20newsgroups-truncated___genetic_correct_pairs.png" alt="Correct pairs - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="2">Spearman correlation for all explanations</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Data</td>
#             <td>Trained 0.78</td>
#         </tr>
#         <tr>
#             <td>Random</td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/20newsgroups-truncated_0_softmax_spearman.png" target="blank"><img src="../results/plots/20newsgroups-truncated___spearman.png" alt="Spearman - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#         <tr>
#             <td>Genetic</td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/20newsgroups-truncated_0_softmax_genetic_spearman.png" target="blank"><img src="../results/plots/20newsgroups-truncated___genetic_spearman.png" alt="Spearman - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="2">Exceptional rankings - AUC</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Data</td>
#             <td>Trained 0.78</td>
#         </tr>
#         <tr>
#             <td>Random</td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/20newsgroups-truncated_0_softmax_auc_exceptional.png" target="blank"><img src="../results/plots/20newsgroups-truncated___auc_exceptional.png" alt="Exceptional AUC - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#         <tr>
#             <td>Genetic</td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/20newsgroups-truncated_0_softmax_genetic_auc_exceptional.png" target="blank"><img src="../results/plots/20newsgroups-truncated___genetic_auc_exceptional.png" alt="Exceptional AUC - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="2">Exceptional rankings - Spearman correlation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Data</td>
#             <td>Trained 0.78</td>
#         </tr>
#         <tr>
#             <td>Random</td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/20newsgroups-truncated_0_softmax_spearman_exceptional.png" target="blank"><img src="../results/plots/20newsgroups-truncated___spearman_exceptional.png" alt="Exceptional Spearman - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#         <tr>
#             <td>Genetic</td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/20newsgroups-truncated_0_softmax_genetic_spearman_exceptional.png" target="blank"><img src="../results/plots/20newsgroups-truncated___genetic_spearman_exceptional.png" alt="Exceptional Spearman - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>
