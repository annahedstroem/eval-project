# %% [markdown]
# <h1>Avila dataset</h1>
# <table>
#     <thead>
#         <tr>
#             <th colspan="5">Correct pairs</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_correct_pairs.png" target="blank"><img src="../results/plots/avila_correct_pairs.png" alt="Correct pairs - Trained" style="width:100%"></a>
#                     <figcaption align = "center"><b>Trained</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_ood_zeros_correct_pairs.png" target="blank"><img src="../results/plots/avila_ood_zeros_correct_pairs.png" alt="Correct pairs - OOD Zeros" style="width:100%"></a>
#                     <figcaption align = "center"><b>OOD trained with zeros</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_ood_mean_correct_pairs.png" target="blank"><img src="../results/plots/avila_ood_mean_correct_pairs.png" alt="Correct pairs - OOD Average" style="width:100%"></a>
#                     <figcaption align = "center"><b>OOD trained with average</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_undertrained_correct_pairs.png" target="blank"><img src="../results/plots/avila_undertrained_correct_pairs.png" alt="Correct pairs - OOD Average" style="width:100%"></a>
#                     <figcaption align = "center"><b>Undertrained</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_untrained_correct_pairs.png" target="blank"><img src="../results/plots/avila_untrained_correct_pairs.png" alt="Correct pairs - Untrained" style="width:100%"></a>
#                     <figcaption align = "center"><b>Untrained</b></figcaption>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="5">Spearman correlation for all explanations</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_spearman.png" target="blank"><img src="../results/plots/avila_spearman.png" alt="Spearman - Trained" style="width:100%"></a>
#                     <figcaption align = "center"><b>Trained</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_ood_zeros_spearman.png" target="blank"><img src="../results/plots/avila_ood_zeros_spearman.png" alt="Spearman - OOD zeros" style="width:100%"></a>
#                     <figcaption align = "center"><b>OOD trained with zeros</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_ood_mean_spearman.png" target="blank"><img src="../results/plots/avila_ood_mean_spearman.png" alt="Spearman - OOD average" style="width:100%"></a>
#                     <figcaption align = "center"><b>OOD trained with average</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                    <a href="../results/plots/avila_undertrained_spearman.png" target="blank"><img src="../results/plots/avila_undertrained_spearman.png" alt="Spearman - Untrained" style="width:100%"></a>
#                     <figcaption align = "center"><b>Undertrained</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_untrained_spearman.png" target="blank"><img src="../results/plots/avila_untrained_spearman.png" alt="Spearman - Untrained" style="width:100%"></a>
#                     <figcaption align = "center"><b>Untrained</b></figcaption>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="5">Exceptional rankings - AUC</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_auc_exceptional.png" target="blank"><img src="../results/plots/avila_auc_exceptional.png" alt="Exceptional AUC - Trained" style="width:100%"></a>
#                     <figcaption align = "center"><b>Trained</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_ood_zeros_auc_exceptional.png" target="blank"><img src="../results/plots/avila_ood_zeros_auc_exceptional.png" alt="Exceptional AUC - OOD Zeros" style="width:100%"></a>
#                     <figcaption align = "center"><b>OOD trained with zeros</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_ood_mean_auc_exceptional.png" target="blank"><img src="../results/plots/avila_ood_mean_auc_exceptional.png" alt="Exceptional AUC - OOD Average" style="width:100%"></a>
#                     <figcaption align = "center"><b>OOD trained with average</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_undertrained_auc_exceptional.png" target="blank"><img src="../results/plots/avila_undertrained_auc_exceptional.png" alt="Exceptional AUC - Untrained" style="width:100%"></a>
#                     <figcaption align = "center"><b>Undertrained</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_untrained_auc_exceptional.png" target="blank"><img src="../results/plots/avila_untrained_auc_exceptional.png" alt="Exceptional AUC - Untrained" style="width:100%"></a>
#                     <figcaption align = "center"><b>Untrained</b></figcaption>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="5">Exceptional rankings - Spearman correlation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_spearman_exceptional.png" target="blank"><img src="../results/plots/avila_spearman_exceptional.png" alt="Exceptional Spearman - Trained" style="width:100%"></a>
#                     <figcaption align = "center"><b>Trained</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_ood_zeros_spearman_exceptional.png" target="blank"><img src="../results/plots/avila_ood_zeros_spearman_exceptional.png" alt="Exceptional Spearman - OOD Zeros" style="width:100%"></a>
#                     <figcaption align = "center"><b>OOD trained with zeros</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_ood_mean_spearman_exceptional.png" target="blank"><img src="../results/plots/avila_ood_mean_spearman_exceptional.png" alt="Exceptional Spearman - OOD Average" style="width:100%"></a>
#                     <figcaption align = "center"><b>OOD trained with average</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_undertrained_spearman_exceptional.png" target="blank"><img src="../results/plots/avila_undertrained_spearman_exceptional.png" alt="Exceptional Spearman - Untrained" style="width:100%"></a>
#                     <figcaption align = "center"><b>Underetrained</b></figcaption>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/avila_untrained_spearman_exceptional.png" target="blank"><img src="../results/plots/avila_untrained_spearman_exceptional.png" alt="Exceptional Spearman - Untrained" style="width:100%"></a>
#                     <figcaption align = "center"><b>Untrained</b></figcaption>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>
