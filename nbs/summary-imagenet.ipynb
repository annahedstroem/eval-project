# %% [markdown]
# <h1>Imagenet dataset</h1>
# <table>
#     <thead>
#         <tr>
#             <th colspan="2">Qmean distributions</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td colspan="2">These plots show the distribution of qmean for each sample used. The activation of the explained class in the model is shown between brackets in the legend.
#             </td>
#         </tr>
#         <tr>
#             <td>ResNet50</td>
#             <td>VGG16</td>
#         </tr>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/imagenet_resnet50_qmean_dists.png" target="blank"><img src="../results/plots/imagenet_resnet50_qmean_dists.png" alt="Qmean distributions - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/imagenet_vgg16_qmean_dists.png" target="blank"><img src="../results/plots/imagenet_vgg16_qmean_dists.png" alt="Qmean distributions - OOD Average" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="2">Correct pairs</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>ResNet50</td>
#             <td>VGG16</td>
#         </tr>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/imagenet_resnet50_correct_pairs.png" target="blank"><img src="../results/plots/imagenet_resnet50_correct_pairs.png" alt="Correct pairs - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/imagenet_vgg16_correct_pairs.png" target="blank"><img src="../results/plots/imagenet_vgg16_correct_pairs.png" alt="Correct pairs - OOD Average" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="2">Spearman correlation for all explanations</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>ResNet50</td>
#             <td>VGG16</td>
#         </tr>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/imagenet_resnet50_spearman.png" target="blank"><img src="../results/plots/imagenet_resnet50_spearman.png" alt="Spearman - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/imagenet_vgg16_spearman.png" target="blank"><img src="../results/plots/imagenet_vgg16_spearman.png" alt="Spearman - OOD average" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="2">Exceptional rankings - AUC</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>ResNet50</td>
#             <td>VGG16</td>
#         </tr>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/imagenet_resnet50_auc_exceptional.png" target="blank"><img src="../results/plots/imagenet_resnet50_auc_exceptional.png" alt="Exceptional AUC - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/imagenet_vgg16_auc_exceptional.png" target="blank"><img src="../results/plots/imagenet_vgg16_auc_exceptional.png" alt="Exceptional AUC - OOD Average" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="2">Exceptional rankings - Spearman correlation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>ResNet50</td>
#             <td>VGG16</td>
#         </tr>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/imagenet_resnet50_spearman_exceptional.png" target="blank"><img src="../results/plots/imagenet_resnet50_spearman_exceptional.png" alt="Exceptional Spearman - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/imagenet_vgg16_spearman_exceptional.png" target="blank"><img src="../results/plots/imagenet_vgg16_spearman_exceptional.png" alt="Exceptional Spearman - OOD Average" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>
