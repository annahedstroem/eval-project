# %% [markdown]
# <h1>Glass dataset</h1>
# <table>
#     <thead>
#         <tr>
#             <th colspan="5">Qmean distributions</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td colspan="5">These plots show the distribution of qmean for each sample used (named 10, 20, 30, 40, and 50, respectively). The activation of the explained class in the model is shown between brackets in the legend.
#             <br />
#             Apparently, the more a model has been trained on the data, the more varied the qmean values, that is, the quality of the explanations has a wider range.
#             <br />
#             Model test accuracy is listed next to the model name.
#             </td>
#         </tr>
#         <tr>
#             <td>Trained 0.77</td>
#             <td>OODzeros 0.63</td>
#             <td>OODmean 0.63</td>
#             <td>Undertrained 0.60</td>
#             <td>Untrained 0.23</td>
#         </tr>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_0_qmean_dists.png" target="blank"><img src="../results/plots/glass_0_qmean_dists.png" alt="Qmean distributions - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_ood-zeros_qmean_dists.png" target="blank"><img src="../results/plots/glass_ood-zeros_qmean_dists.png" alt="Qmean distributions - OOD Zeros" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_ood-mean_qmean_dists.png" target="blank"><img src="../results/plots/glass_ood-mean_qmean_dists.png" alt="Qmean distributions - OOD Average" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_undertrained_qmean_dists.png" target="blank"><img src="../results/plots/glass_undertrained_qmean_dists.png" alt="Qmean distributions - OOD Average" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_untrained_qmean_dists.png" target="blank"><img src="../results/plots/glass_untrained_qmean_dists.png" alt="Qmean distributions - Untrained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="5">Correct pairs</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Trained 0.77</td>
#             <td>OODzeros 0.63</td>
#             <td>OODmean 0.63</td>
#             <td>Undertrained 0.60</td>
#             <td>Untrained 0.23</td>
#         </tr>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_0_correct_pairs.png" target="blank"><img src="../results/plots/glass_0_correct_pairs.png" alt="Correct pairs - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_ood-zeros_correct_pairs.png" target="blank"><img src="../results/plots/glass_ood-zeros_correct_pairs.png" alt="Correct pairs - OOD Zeros" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_ood-mean_correct_pairs.png" target="blank"><img src="../results/plots/glass_ood-mean_correct_pairs.png" alt="Correct pairs - OOD Average" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_undertrained_correct_pairs.png" target="blank"><img src="../results/plots/glass_undertrained_correct_pairs.png" alt="Correct pairs - OOD Average" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_untrained_correct_pairs.png" target="blank"><img src="../results/plots/glass_untrained_correct_pairs.png" alt="Correct pairs - Untrained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="5">Spearman correlation for all explanations</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Trained 0.77</td>
#             <td>OODzeros 0.63</td>
#             <td>OODmean 0.63</td>
#             <td>Undertrained 0.60</td>
#             <td>Untrained 0.23</td>
#         </tr>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_0_spearman.png" target="blank"><img src="../results/plots/glass_0_spearman.png" alt="Spearman - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_ood-zeros_spearman.png" target="blank"><img src="../results/plots/glass_ood-zeros_spearman.png" alt="Spearman - OOD zeros" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_ood-mean_spearman.png" target="blank"><img src="../results/plots/glass_ood-mean_spearman.png" alt="Spearman - OOD average" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                    <a href="../results/plots/glass_undertrained_spearman.png" target="blank"><img src="../results/plots/glass_undertrained_spearman.png" alt="Spearman - Untrained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_untrained_spearman.png" target="blank"><img src="../results/plots/glass_untrained_spearman.png" alt="Spearman - Untrained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="5">Exceptional rankings - AUC</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Trained 0.77</td>
#             <td>OODzeros 0.63</td>
#             <td>OODmean 0.63</td>
#             <td>Undertrained 0.60</td>
#             <td>Untrained 0.23</td>
#         </tr>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_0_auc_exceptional.png" target="blank"><img src="../results/plots/glass_0_auc_exceptional.png" alt="Exceptional AUC - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_ood-zeros_auc_exceptional.png" target="blank"><img src="../results/plots/glass_ood-zeros_auc_exceptional.png" alt="Exceptional AUC - OOD Zeros" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_ood-mean_auc_exceptional.png" target="blank"><img src="../results/plots/glass_ood-mean_auc_exceptional.png" alt="Exceptional AUC - OOD Average" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_undertrained_auc_exceptional.png" target="blank"><img src="../results/plots/glass_undertrained_auc_exceptional.png" alt="Exceptional AUC - Untrained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_untrained_auc_exceptional.png" target="blank"><img src="../results/plots/glass_untrained_auc_exceptional.png" alt="Exceptional AUC - Untrained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th colspan="5">Exceptional rankings - Spearman correlation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Trained 0.77</td>
#             <td>OODzeros 0.63</td>
#             <td>OODmean 0.63</td>
#             <td>Undertrained 0.60</td>
#             <td>Untrained 0.23</td>
#         </tr>
#         <tr>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_0_spearman_exceptional.png" target="blank"><img src="../results/plots/glass_0_spearman_exceptional.png" alt="Exceptional Spearman - Trained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_ood-zeros_spearman_exceptional.png" target="blank"><img src="../results/plots/glass_ood-zeros_spearman_exceptional.png" alt="Exceptional Spearman - OOD Zeros" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_ood-mean_spearman_exceptional.png" target="blank"><img src="../results/plots/glass_ood-mean_spearman_exceptional.png" alt="Exceptional Spearman - OOD Average" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_undertrained_spearman_exceptional.png" target="blank"><img src="../results/plots/glass_undertrained_spearman_exceptional.png" alt="Exceptional Spearman - Untrained" style="width:100%"></a>
#                 </figure>
#             </td>
#             <td>
#                 <figure>
#                     <a href="../results/plots/glass_untrained_spearman_exceptional.png" target="blank"><img src="../results/plots/glass_untrained_spearman_exceptional.png" alt="Exceptional Spearman - Untrained" style="width:100%"></a>
#                 </figure>
#             </td>
#         </tr>
#     </tbody>
# </table>
